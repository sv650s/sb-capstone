# %%
import math

# %%
def step_decay(epoch):
    initial_lrate = 0.0001
    drop = 0.85
    epochs_drop = 2.0
    lrate = initial_lrate * math.pow(drop,  
               math.floor((1+epoch)/epochs_drop))
    return lrate

# %%
for i in range(30):
    print(i, step_decay(i))
# Out:
# 0 0.0001
# 1 8.5e-05
# 2 8.5e-05
# 3 7.225e-05
# 4 7.225e-05
# 5 6.14125e-05
# 6 6.14125e-05
# 7 5.220062499999999e-05
# 8 5.220062499999999e-05
# 9 4.4370531249999995e-05
# 10 4.4370531249999995e-05
# 11 3.77149515625e-05
# 12 3.77149515625e-05
# 13 3.2057708828124995e-05
# 14 3.2057708828124995e-05
# 15 2.7249052503906248e-05
# 16 2.7249052503906248e-05
# 17 2.3161694628320308e-05
# 18 2.3161694628320308e-05
# 19 1.968744043407226e-05
# 20 1.968744043407226e-05
# 21 1.673432436896142e-05
# 22 1.673432436896142e-05
# 23 1.4224175713617208e-05
# 24 1.4224175713617208e-05
# 25 1.2090549356574626e-05
# 26 1.2090549356574626e-05
# 27 1.0276966953088432e-05
# 28 1.0276966953088432e-05
# 29 8.735421910125167e-06

# %%
7.5 * 10 ** -4
# Out:
# 0.00075

# %%
import pandas as pd

# %%
df = pd.read_table('dataset/amazon_reviews/amazon_reviews_us_Wireless_v1_00-error.tsv')
df.shape
# Out:
# /Users/vinceluk/anaconda3/envs/capstone/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
# (27, 15)

# %%
df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     19333916  R1AQ5D1SFH1UCW  B00JH882JW       878254697
# 1          US     27593825  R21U7PJCM98QQF  B00SYA3FTQ       104756313
# 2          US     22684872   RIPG13XN1OEJY  B00MJ81PYQ       469359817
# 3          US      5975621  R13XJO03RAH9PP  B00YHUGZ1W        81256566
# 4          US     50684753   RKUM9T6ZN2G9M  B00DI67RTK       474566116
#
#                                        product_title product_category  \
# 0  Spigen Liquid Air iPhone 6 Case with Durable F...         Wireless
# 1  Samsung Galaxy S5 Glass Screen Protector by Vo...         Wireless
# 2  Galaxy Centura Case, CellJoy® [Future Armor] S...         Wireless
# 3  QualityStores® LG Logos Case / LG Escape2 Case...         Wireless
# 4                                   Wallets iPhone 4         Wireless
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# ...

# %%
import csv
with open('dataset/amazon_reviews/amazon_reviews_us_Wireless_v1_00-error.tsv', 'r+') as old_f, open('new_amazon.csv', 'w+') as new_f:
    writer = csv.writer(new_f)
    for line in old_f:
        data = line.strip('\n').split('\t')
        writer.writerow(data)

# %%
new_df = pd.read_csv('new_amazon.csv', sep=',')
new_df.shape
# Out:
# (79, 15)

# %%
new_df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     19333916  R1AQ5D1SFH1UCW  B00JH882JW       878254697
# 1          US     27593825  R21U7PJCM98QQF  B00SYA3FTQ       104756313
# 2          US     26952783  R3O4ERCN3DTXQO  B00SWQV4JA       646700147
# 3          US      2275966  R3LHVUEFR2AGAE  B00IX5YOG0       963886012
# 4          US       430034  R2L43OCW0MIK11  B00LXL6ZKO       129044147
#
#                                        product_title product_category  \
# 0  Spigen Liquid Air iPhone 6 Case with Durable F...         Wireless
# 1  Samsung Galaxy S5 Glass Screen Protector by Vo...         Wireless
# 2  MOONCASE Premium PU Leather Slim Flip Bracket ...         Wireless
# 3                         S5 HSERIES CASES, BUDDIBOX         Wireless
# 4  Samsung Galaxy S3 S III Mini Original OEM Batt...         Wireless
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# ...
