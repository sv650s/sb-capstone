# %% [markdown]
# # Clean up network history
#
# Similar to https://colab.research.google.com/drive/1DdYPOcXxg7CmRFtpjHdmFUtPj7t2GGSq#scrollTo=bGvwRn-nyPVS
#
# We are going to convert network history from files to json in the report

# %%
import os
import pandas as pd
import numpy as np
import pickle
import json

import sys
sys.path.append('../../')


from functools import singledispatch

@singledispatch
def to_serializable(val):
    """Used by default."""
    return str(val)

@to_serializable.register(np.float32)
def ts_float32(val):
    """Used if *val* is an instance of numpy.float32."""
    return np.float64(val)

# %%
DRIVE_DIR = '../../'
REPORT_DIR = f'{DRIVE_DIR}/reports'


def convert_history(reports: list, debug: bool = True) -> list:

  convert_history = {}

  for report_basename in reports:
    report_file = f'{DRIVE_DIR}/reports/{report_basename}'
    report_file_bak = f'{report_file}.pre-network-history'

    converted_files = []

    print(f"\n\nReading {os.path.basename(report_file)}")
    if "run_classifier" in report_basename:
        df = pd.read_csv(report_file)
    else:
        df = pd.read_csv(report_file, quotechar="'")
    if not debug:
      # backing up old file
      print(f'Backing up to {os.path.basename(report_file_bak)}')
      df.to_csv(report_file_bak, index = False, quotechar="'")

    if "network_history_file" in df.columns:
        for idx, row in df.iterrows():

          if "network_history_file" in row.index and isinstance(row.network_history_file, str) and len(row.network_history_file) > 0:
            if "network_history" not in row.index or row.network_history is np.NaN or len(row.network_history) == 0:
              print(f"converting network history {row.network_history_file}...")
              history_file = f'{DRIVE_DIR}/reports/{os.path.basename(row.network_history_file)}'

              if os.path.exists(history_file):
                print(f"loading {os.path.basename(history_file)}")
                with open(history_file, 'rb') as file:
                  network_history = pickle.load(file)
                  # print(network_history)


                converted_files.append(row.network_history_file)
                df.loc[idx, "network_history"] = json.dumps(network_history, default=to_serializable)
                df.loc[idx, "network_history_file"] = np.NaN
              else:
                print(f'Cannot locate: {history_file}')
                df.loc[idx, "network_history_file"] = np.NaN

            else:
              print("network_history already exists")

        convert_history[report_basename] = converted_files

        if "network_history" in df.columns:
          print(df[["network_history_file", "network_history"]])
        else:
          print(f'Nothing to convert {report_basename}')
        # TODO: overwrite file
        if not debug:
          print(f'Saving {os.path.basename(report_file)}')
          df.to_csv(f'{report_file}', index = False, quotechar="'")

  return convert_history



reports = [file for file in os.listdir(f'{REPORT_DIR}') 
           if file.endswith("report.csv") and not "feature_generator" in file]

history_dict = convert_history(reports, debug = False)
# Out:
# Reading 2020-05-dl_prototype-report.csv
# Backing up to 2020-05-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.6073917150497437, 1.57548284530639...
# Saving 2020-05-dl_prototype-report.csv
#
#
# Reading 2019-11-01-run_classifiers-50k-report.csv
# Backing up to 2019-11-01-run_classifiers-50k-report.csv.pre-network-history
#
#
# Reading LSTMB128_dr2_rdr2_batch128_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv
# Backing up to LSTMB128_dr2_rdr2_batch128_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.3436235189437866, 1.23250436782836...
# Saving LSTMB128_dr2_rdr2_batch128_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv
#
#
# Reading LSTMB128_dr0_rdr2_batch32_lr01-glove_with_stop_nonlemmatized-dl_prototype-report.csv
# Backing up to LSTMB128_dr0_rdr2_batch32_lr01-glove_with_stop_nonlemmatized-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.353121042251587, 1.125137448310852...
# 1                   NaN  {"loss": [1.134163498878479, 1.047209739685058...
# Saving LSTMB128_dr0_rdr2_batch32_lr01-glove_with_stop_nonlemmatized-dl_prototype-report.csv
#
#
# Reading glove_embedding_with_stop_nonlemmatized-dl_prototype-report.csv
# Backing up to glove_embedding_with_stop_nonlemmatized-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [0.8622924961667269, 0.77974169783644...
# 1                   NaN  {"loss": [0.7218489510438479, 0.64632683364609...
# 2                   NaN  {"loss": [0.536843494671173, 0.470519316535442...
# 3                   NaN  {"loss": [0.14838366687507357, 0.0966473366105...
# Saving glove_embedding_with_stop_nonlemmatized-dl_prototype-report.csv
#
#
# Reading 2020-01-dl_prototype-report.csv
# Backing up to 2020-01-dl_prototype-report.csv.pre-network-history
#
#
# Reading LSTMB16_dr0_rdr2_batch32_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv
# Backing up to LSTMB16_dr0_rdr2_batch32_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.314558506011963, 1.218946337699890...
# Saving LSTMB16_dr0_rdr2_batch32_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv
#
#
# Reading LSTMB128_dr0_rdr0_batch128_lr01-glove_with_stop_nonlemmatized-dl_prototype-report.csv
# Backing up to LSTMB128_dr0_rdr0_batch128_lr01-glove_with_stop_nonlemmatized-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.2241685390472412, 1.05145764350891...
# 1                   NaN  {"loss": [1.1360876560211182, 0.99884390830993...
# Saving LSTMB128_dr0_rdr0_batch128_lr01-glove_with_stop_nonlemmatized-dl_prototype-report.csv
#
#
# Reading glove_embedding_with_stop-dl_prototype-report.csv
# Backing up to glove_embedding_with_stop-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [0.864987526549673, 0.781224966492090...
# 1                   NaN  {"loss": [0.15091132934567544, 0.0967333125631...
# 2                   NaN  {"loss": [0.7243854221577091, 0.64916626098978...
# 3                   NaN  {"loss": [0.537360964129338, 0.471968650956154...
# Saving glove_embedding_with_stop-dl_prototype-report.csv
#
#
# Reading LSTM-cell-tuning-report.csv
# Backing up to LSTM-cell-tuning-report.csv.pre-network-history
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-99772-100-review_body-history.pkl...
# Cannot locate: ../..//reports/LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-99772-100-review_body-history.pkl
#   network_history_file                                    network_history
# 0                  NaN  {"loss": [1.3007395267486572, 1.17178082466125...
# 1                  NaN  {"loss": [1.261155128479004, 1.125839710235595...
# 2                  NaN  {"loss": [1.2541470527648926, 1.10766685009002...
# 3                  NaN                                                NaN
# Saving LSTM-cell-tuning-report.csv
#
#
# Reading 2020-02-dl_prototype-report.csv
# Backing up to 2020-02-dl_prototype-report.csv.pre-network-history
# converting network history drive/My Drive/Springboard/capstone/models/test-LSTMB16-1x16-glove-sampling_none-99-100-star_rating-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB16-1x16-glove-sampling_none-99-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/models/test-LSTMB16-1x16-glove-sampling_none-99-100-star_rating-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB16-1x16-glove-sampling_none-99-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/models/test-LSTMB16-1x16-glove-sampling_none-99-100-star_rating-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB16-1x16-glove-sampling_none-99-100-star_rating-history.pkl
#    network_history_file                                    network_history
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# 5                   NaN                                                NaN
# 6                   NaN                                                NaN
# 7                   NaN                                                NaN
# 8                   NaN                                                NaN
# 9                   NaN                                                NaN
# 10                  NaN                                                NaN
# 11                  NaN                                                NaN
# 12                  NaN                                                NaN
# 13                  NaN                                                NaN
# 14                  NaN  {"loss": [0.7399054765701294, 0.69176816940307...
# 15                  NaN  {"loss": [0.7399054765701294, 0.69176816940307...
# 16                  NaN  {"loss": [1.6100393533706665, 1.56758916378021...
# 17                  NaN  {"loss": [1.6100393533706665, 1.56758916378021...
# 18                  NaN  {"loss": [1.6100393533706665, 1.56758916378021...
# Saving 2020-02-dl_prototype-report.csv
#
#
# Reading 2019-11-dl_prototype-report.csv
# Backing up to 2019-11-dl_prototype-report.csv.pre-network-history
# Nothing to convert 2019-11-dl_prototype-report.csv
# Saving 2019-11-dl_prototype-report.csv
#
#
# Reading 2019-11-run_classifiers-lrb-report.csv
# Backing up to 2019-11-run_classifiers-lrb-report.csv.pre-network-history
#
#
# Reading 2019-07-31-dl_protype-report.csv
# Backing up to 2019-07-31-dl_protype-report.csv.pre-network-history
# converting network history <keras.callbacks.History object at 0x7f5403610048>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f5403610048>
# converting network history <keras.callbacks.History object at 0x7f6df2f587b8>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f6df2f587b8>
# converting network history <keras.callbacks.History object at 0x7fab83bd1550>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7fab83bd1550>
# converting network history <keras.callbacks.History object at 0x7f62cd50ffd0>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f62cd50ffd0>
# converting network history <keras.callbacks.History object at 0x7f469db69c18>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f469db69c18>
# converting network history <keras.callbacks.History object at 0x7f141a65a4a8>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f141a65a4a8>
# converting network history <keras.callbacks.History object at 0x7f698f2147f0>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f698f2147f0>
# converting network history <keras.callbacks.History object at 0x7f6862141048>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f6862141048>
# converting network history <keras.callbacks.History object at 0x7f4346ce7dd8>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f4346ce7dd8>
# converting network history <keras.callbacks.History object at 0x7f9761a8a160>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f9761a8a160>
# converting network history <keras.callbacks.History object at 0x7fb91eb86978>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7fb91eb86978>
# converting network history <keras.callbacks.History object at 0x7fe5feef9da0>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7fe5feef9da0>
# converting network history <keras.callbacks.History object at 0x7f63587de390>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f63587de390>
# converting network history <keras.callbacks.History object at 0x7f634cdbb0f0>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f634cdbb0f0>
# converting network history <keras.callbacks.History object at 0x7f950c15c898>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f950c15c898>
# converting network history <keras.callbacks.History object at 0x7f9504635e10>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f9504635e10>
# Nothing to convert 2019-07-31-dl_protype-report.csv
# Saving 2019-07-31-dl_protype-report.csv
#
#
# Reading 2019-11-01-run_classifiers-svc-report.csv
# Backing up to 2019-11-01-run_classifiers-svc-report.csv.pre-network-history
#
#
# Reading headline-glove_embedding_with_stop_nonlemmatized-dl_prototype-report.csv
# Backing up to headline-glove_embedding_with_stop_nonlemmatized-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [0.749079482680229, 0.694326500427693...
# 1                   NaN  {"loss": [0.7204609159538196, 0.68099378211495...
# Saving headline-glove_embedding_with_stop_nonlemmatized-dl_prototype-report.csv
#
#
# Reading LSTM-preprocessing-tuning-report.csv
# Backing up to LSTM-preprocessing-tuning-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [0.9530231356620789, 0.84709024429321...
# 1                   NaN  {"loss": [0.9530231356620789, 0.84709024429321...
# 2                   NaN  {"loss": [0.9530231356620789, 0.84709024429321...
# 3                   NaN  {"loss": [0.9530231356620789, 0.84709024429321...
# Saving LSTM-preprocessing-tuning-report.csv
#
#
# Reading LSTM-dropout-tuning-report.csv
# Backing up to LSTM-dropout-tuning-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.2789909839630127, 1.15177631378173...
# 1                   NaN  {"loss": [1.2789909839630127, 1.15177631378173...
# 2                   NaN  {"loss": [1.2789909839630127, 1.15177631378173...
# 3                   NaN  {"loss": [1.3007395267486572, 1.17178082466125...
# Saving LSTM-dropout-tuning-report.csv
#
#
# Reading glove_embedding-dl_prototype-report.csv
# Backing up to glove_embedding-dl_prototype-report.csv.pre-network-history
# converting network history drive/My Drive/Springboard/capstone/models/biGRU16-1x16-glove-sampling_none-199134-100-star_rating-history.pkl...
# loading biGRU16-1x16-glove-sampling_none-199134-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/models/LSTMB16-1x16-glove-sampling_none-2000000-100-star_rating-history.pkl...
# Cannot locate: ../..//reports/LSTMB16-1x16-glove-sampling_none-2000000-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/models/biGRU16-1x16-glove-sampling_none-497835-100-star_rating-history.pkl...
# loading biGRU16-1x16-glove-sampling_none-497835-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/models/biGRU16-1x16-glove-sampling_none-995688-100-star_rating-history.pkl...
# loading biGRU16-1x16-glove-sampling_none-995688-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/models/biGRU16-1x16-glove-sampling_none-2000000-100-star_rating-history.pkl...
# loading biGRU16-1x16-glove-sampling_none-2000000-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/models/LSTMB16-1x16-glove-sampling_none-497835-100-star_rating-history.pkl...
# Cannot locate: ../..//reports/LSTMB16-1x16-glove-sampling_none-497835-100-star_rating-history.pkl
#    network_history_file                                    network_history
# 0                   NaN                                                NaN
# 1                   NaN  {"loss": [0.9928409402091886, 0.84443080419276...
# 2                   NaN                                                NaN
# 3                   NaN  {"loss": [0.9012998796355417, 0.80273838093339...
# 4                   NaN  {"loss": [0.8551628216325374, 0.78543230886418...
# 5                   NaN  {"loss": [0.8233210589090983, 0.77355184913635...
# 6                   NaN                                                NaN
# 7                   NaN  {"loss": [0.1435026780157967, 0.09747473491591...
# 8                   NaN  {"loss": [0.1704080996563167, 0.11089829540018...
# 9                   NaN  {"loss": [0.22036331948561838, 0.1419918946629...
# 10                  NaN  {"loss": [0.1223850853640002, 0.08917970064133...
# 11                  NaN  {"loss": [0.8660581327841252, 0.79266720070840...
# 12                  NaN  {"loss": [0.5314411877441242, 0.47468157496715...
# 13                  NaN  {"loss": [0.721858765339363, 0.656801149044417...
# Saving glove_embedding-dl_prototype-report.csv
#
#
# Reading LSTMB128_dr0_rdr0_batch32_lr01-glove_with_stop_nonlemmatized-dl_prototype-report.csv
# Backing up to LSTMB128_dr0_rdr0_batch32_lr01-glove_with_stop_nonlemmatized-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.1809697151184082, 1.06573367118835...
# 1                   NaN  {"loss": [1.099169373512268, 1.128992557525634...
# Saving LSTMB128_dr0_rdr0_batch32_lr01-glove_with_stop_nonlemmatized-dl_prototype-report.csv
#
#
# Reading LSTMB128_dr2_rdr2_batch32_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv
# Backing up to LSTMB128_dr2_rdr2_batch32_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.303430199623108, 1.164995312690734...
# Saving LSTMB128_dr2_rdr2_batch32_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv
#
#
# Reading 201911-run_classifiers-sampling-report.csv
# Backing up to 201911-run_classifiers-sampling-report.csv.pre-network-history
#
#
# Reading 2019-07-23-DNN_protype-report.csv
# Backing up to 2019-07-23-DNN_protype-report.csv.pre-network-history
# Nothing to convert 2019-07-23-DNN_protype-report.csv
# Saving 2019-07-23-DNN_protype-report.csv
#
#
# Reading lstm_remove_all_dropout-dl_prototype-report.csv
# Backing up to lstm_remove_all_dropout-dl_prototype-report.csv.pre-network-history
#
#
# Reading converted-history-report.csv
# Backing up to converted-history-report.csv.pre-network-history
#
#
# Reading LSTMB128_dr2_rdr2_batch128_lr01-glove_with_stop_nonlemmatized-dl_prototype-report.csv
# Backing up to LSTMB128_dr2_rdr2_batch128_lr01-glove_with_stop_nonlemmatized-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.2660737037658691, 1.08989906311035...
# 1                   NaN  {"loss": [1.1571786403656006, 1.03079557418823...
# Saving LSTMB128_dr2_rdr2_batch128_lr01-glove_with_stop_nonlemmatized-dl_prototype-report.csv
#
#
# Reading 2019-07-24-DNN_protype-report.csv
# Backing up to 2019-07-24-DNN_protype-report.csv.pre-network-history
# Nothing to convert 2019-07-24-DNN_protype-report.csv
# Saving 2019-07-24-DNN_protype-report.csv
#
#
# Reading paperspace-LSTMB128-1x128-dr2-rdr2-batch128-lr01-glove_with_stop_nonlemmatized-sampling_none-review_body-report.csv
# Backing up to paperspace-LSTMB128-1x128-dr2-rdr2-batch128-lr01-glove_with_stop_nonlemmatized-sampling_none-review_body-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.0081106424331665, 1.05121648311615...
# Saving paperspace-LSTMB128-1x128-dr2-rdr2-batch128-lr01-glove_with_stop_nonlemmatized-sampling_none-review_body-report.csv
#
#
# Reading LSTMB128_dr0_rdr0_batch128_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv
# Backing up to LSTMB128_dr0_rdr0_batch128_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.3176101446151733, 1.19225049018859...
# Saving LSTMB128_dr0_rdr0_batch128_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv
#
#
# Reading LSTMB128_dr0_rdr0_batch32_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv
# Backing up to LSTMB128_dr0_rdr0_batch32_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.2671301364898682, 1.12838721275329...
# 1                   NaN  {"loss": [1.2073763608932495, 1.06562340259552...
# Saving LSTMB128_dr0_rdr0_batch32_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv
#
#
# Reading 2020-04-dl_prototype-report.csv
# Backing up to 2020-04-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.6213127374649048], "categorical_ac...
# Saving 2020-04-dl_prototype-report.csv
#
#
# Reading 2019-08-03-dl_prototype-report.csv
# Backing up to 2019-08-03-dl_prototype-report.csv.pre-network-history
# converting network history <keras.callbacks.History object at 0x7f69a4594c18>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f69a4594c18>
# converting network history <keras.callbacks.History object at 0x7fd0ebd1e748>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7fd0ebd1e748>
# converting network history <keras.callbacks.History object at 0x7f232e83fda0>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f232e83fda0>
# converting network history <keras.callbacks.History object at 0x7f6142538860>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f6142538860>
# Nothing to convert 2019-08-03-dl_prototype-report.csv
# Saving 2019-08-03-dl_prototype-report.csv
#
#
# Reading LSTMB128_dr0_rdr2_batch32_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv
# Backing up to LSTMB128_dr0_rdr2_batch32_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.3109344244003296, 1.15510392189025...
# 1                   NaN  {"loss": [1.2242082357406616, 1.13570034503936...
# 2                   NaN  {"loss": [1.1941879987716675, 1.05147123336792...
# 3                   NaN  {"loss": [1.2755681276321411, 1.14204192161560...
# 4                   NaN  {"loss": [1.0622637271881104, 0.97020518779754...
# Saving LSTMB128_dr0_rdr2_batch32_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv
#
#
# Reading 2019-07-30-dl_protype-report.csv
# Backing up to 2019-07-30-dl_protype-report.csv.pre-network-history
# converting network history <keras.callbacks.History object at 0x7f5403610048>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f5403610048>
# converting network history <keras.callbacks.History object at 0x7f6df2f587b8>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f6df2f587b8>
# converting network history <keras.callbacks.History object at 0x7fab83bd1550>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7fab83bd1550>
# converting network history <keras.callbacks.History object at 0x7f62cd50ffd0>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f62cd50ffd0>
# converting network history <keras.callbacks.History object at 0x7f469db69c18>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f469db69c18>
# converting network history <keras.callbacks.History object at 0x7f141a65a4a8>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f141a65a4a8>
# converting network history <keras.callbacks.History object at 0x7f698f2147f0>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f698f2147f0>
# converting network history <keras.callbacks.History object at 0x7f6862141048>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f6862141048>
# converting network history <keras.callbacks.History object at 0x7f4346ce7dd8>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f4346ce7dd8>
# converting network history <keras.callbacks.History object at 0x7f9761a8a160>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f9761a8a160>
# converting network history <keras.callbacks.History object at 0x7fb91eb86978>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7fb91eb86978>
# converting network history <keras.callbacks.History object at 0x7fe5feef9da0>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7fe5feef9da0>
# converting network history <keras.callbacks.History object at 0x7f63587de390>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f63587de390>
# converting network history <keras.callbacks.History object at 0x7f634cdbb0f0>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f634cdbb0f0>
# converting network history <keras.callbacks.History object at 0x7f950c15c898>...
# Cannot locate: ../..//reports/<keras.callbacks.History object at 0x7f950c15c898>
# Nothing to convert 2019-07-30-dl_protype-report.csv
# Saving 2019-07-30-dl_protype-report.csv
#
#
# Reading LSTM-batch-tuning-report.csv
# Backing up to LSTM-batch-tuning-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.3015918731689453, 1.17139601707458...
# 1                   NaN  {"loss": [1.3259729146957397, 1.19156491756439...
# 2                   NaN  {"loss": [1.3538296222686768, 1.21149897575378...
# Saving LSTM-batch-tuning-report.csv
#
#
# Reading 2019-07-26-dl_protype-report.csv
# Backing up to 2019-07-26-dl_protype-report.csv.pre-network-history
# Nothing to convert 2019-07-26-dl_protype-report.csv
# Saving 2019-07-26-dl_protype-report.csv
#
#
# Reading 201911-run_classifiers-50k-lr_cv-report.csv
# Backing up to 201911-run_classifiers-50k-lr_cv-report.csv.pre-network-history
#
#
# Reading 201911-pyspark-report.csv
# Backing up to 201911-pyspark-report.csv.pre-network-history
#
#
# Reading 2-column-converted-network-history-report.csv
# Backing up to 2-column-converted-network-history-report.csv.pre-network-history
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB16_145-1x16-glove-sampling_none-84-100-star_rating-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB16_145-1x16-glove-sampling_none-84-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB16_1345-1x16-glove-sampling_none-91-100-star_rating-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB16_1345-1x16-glove-sampling_none-91-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16_15-1x16-glove-sampling_none-673881-100-star_rating-history.pkl...
# loading LSTMB16_15-1x16-glove-sampling_none-673881-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16_15-1x16-glove-sampling_none-337040-100-star_rating-history.pkl...
# loading LSTMB16_15-1x16-glove-sampling_none-337040-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16_15-1x16-glove-sampling_none-134678-100-star_rating-history.pkl...
# loading LSTMB16_15-1x16-glove-sampling_none-134678-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16_15-1x16-glove-sampling_none-1352517-100-star_rating-history.pkl...
# loading LSTMB16_15-1x16-glove-sampling_none-1352517-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16-1x16-glove-sampling_none-995688-100-star_rating-history.pkl...
# loading LSTMB16-1x16-glove-sampling_none-995688-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16_145-1x16-glove-sampling_none-839811-100-star_rating-history.pkl...
# loading LSTMB16_145-1x16-glove-sampling_none-839811-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16_1345-1x16-glove-sampling_none-929903-100-star_rating-history.pkl...
# loading LSTMB16_1345-1x16-glove-sampling_none-929903-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16-1x16-glove_with_stop-sampling_none-997682-100-star_rating-history.pkl...
# loading LSTMB16-1x16-glove_with_stop-sampling_none-997682-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16_15-1x16-glove_with_stop-sampling_none-675121-100-star_rating-history.pkl...
# loading LSTMB16_15-1x16-glove_with_stop-sampling_none-675121-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16_1345-1x16-glove_with_stop-sampling_none-931734-100-star_rating-history.pkl...
# loading LSTMB16_1345-1x16-glove_with_stop-sampling_none-931734-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16_145-1x16-glove_with_stop-sampling_none-841233-100-star_rating-history.pkl...
# loading LSTMB16_145-1x16-glove_with_stop-sampling_none-841233-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB16_15-1x16-glove-sampling_none-70-100-star_rating-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB16_15-1x16-glove-sampling_none-70-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB16_15-1x16-glove-sampling_none-70-100-star_rating-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB16_15-1x16-glove-sampling_none-70-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB16-1x16-glove-sampling_none-99-30-star_rating-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB16-1x16-glove-sampling_none-99-30-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-99-30-review_headline-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-99-30-review_headline-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-99-30-review_headline-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-99-30-review_headline-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-997681-30-review_headline-history.pkl...
# loading LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-997681-30-review_headline-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-2244642-30-review_headline-history.pkl...
# loading LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-2244642-30-review_headline-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-999-100-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-999-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-99772-100-review_body-history.pkl...
# loading LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-99772-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB32-1x32-glove_with_stop_nonlemmatized-sampling_none-99772-100-review_body-history.pkl...
# loading LSTMB32-1x32-glove_with_stop_nonlemmatized-sampling_none-99772-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB64-1x64-glove_with_stop_nonlemmatized-sampling_none-99772-100-review_body-history.pkl...
# loading LSTMB64-1x64-glove_with_stop_nonlemmatized-sampling_none-99772-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB16-1x16-glove_with_stop_nonlemmatized_nodropout-sampling_none-99772-100-review_body-history.pkl...
# loading LSTMB16-1x16-glove_with_stop_nonlemmatized_nodropout-sampling_none-99772-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB16-1x16-glove_with_stop_nonlemmatized_nodropout-sampling_none-99772-100-review_body-history.pkl...
# loading LSTMB16-1x16-glove_with_stop_nonlemmatized_nodropout-sampling_none-99772-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB16-1x16-glove_with_stop_nonlemmatized_nodropout-sampling_none-99772-100-review_body-history.pkl...
# loading LSTMB16-1x16-glove_with_stop_nonlemmatized_nodropout-sampling_none-99772-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-99772-100-review_body-history.pkl...
# loading LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-99772-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB16-1x16-batch_32-sampling_none-99772-100-review_body-history.pkl...
# loading LSTMB16-1x16-batch_32-sampling_none-99772-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB16-1x16-batch_64-sampling_none-99772-100-review_body-history.pkl...
# loading LSTMB16-1x16-batch_64-sampling_none-99772-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB16-1x16-batch_128-sampling_none-99772-100-review_body-history.pkl...
# loading LSTMB16-1x16-batch_128-sampling_none-99772-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB16-expandcontractions_removestopwords_lemmatized-1x16-expandcontractions_removestopwords_lemmatized-sampling_none-99567-100-review_body-history.pkl...
# loading LSTMB16-expandcontractions_removestopwords_lemmatized-1x16-expandcontractions_removestopwords_lemmatized-sampling_none-99567-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB16-expandcontractions_removestopwords_lemmatized-1x16-expandcontractions_removestopwords_lemmatized-sampling_none-99567-100-review_body-history.pkl...
# loading LSTMB16-expandcontractions_removestopwords_lemmatized-1x16-expandcontractions_removestopwords_lemmatized-sampling_none-99567-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB16-expandcontractions_removestopwords_lemmatized-1x16-expandcontractions_removestopwords_lemmatized-sampling_none-99567-100-review_body-history.pkl...
# loading LSTMB16-expandcontractions_removestopwords_lemmatized-1x16-expandcontractions_removestopwords_lemmatized-sampling_none-99567-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB16-expandcontractions_removestopwords_lemmatized-1x16-expandcontractions_removestopwords_lemmatized-sampling_none-99567-100-review_body-history.pkl...
# loading LSTMB16-expandcontractions_removestopwords_lemmatized-1x16-expandcontractions_removestopwords_lemmatized-sampling_none-99567-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/test-LSTM16-1x16-random_embedding-sampling_none-99-100-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTM16-1x16-random_embedding-sampling_none-99-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/test-LSTMB16-1x16-random_embedding-sampling_none-99-100-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB16-1x16-random_embedding-sampling_none-99-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/test-LSTMB16-1x16-random_embedding-sampling_none-99-100-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB16-1x16-random_embedding-sampling_none-99-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTM16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl...
# loading LSTM16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl...
# loading LSTMB16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/LSTMB16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl...
# loading LSTMB16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/GRU16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl...
# loading GRU16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/GRU16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl...
# loading GRU16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/biGRUB16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl...
# loading biGRUB16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/CNN32-1x32-embedding_random-sampling_none-200k-review_body-v1-history.pkl...
# loading CNN32-1x32-embedding_random-sampling_none-200k-review_body-v1-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-0.0-0.2-32-glove_with_stop_nonlemmatized-sampling_none-99-100-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-0.0-0.2-32-glove_with_stop_nonlemmatized-sampling_none-99-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-glove_with_stop_nonlemmatized_dropout20-sampling_none-99-100-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-glove_with_stop_nonlemmatized_dropout20-sampling_none-99-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone//reports/test-LSTMB16-1x16-glove_with_stop_nonlemmatized_nodropout-sampling_none-99-100-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB16-1x16-glove_with_stop_nonlemmatized_nodropout-sampling_none-99-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-dr0-rdr0-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-99-100-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-dr0-rdr0-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-99-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-dr0-rdr0-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-99-100-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-dr0-rdr0-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-99-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-dr0-rdr0-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-99-100-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-dr0-rdr0-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-99-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-dr0-rdr0-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-99-100-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-dr0-rdr0-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-99-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl...
# loading LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-dr0-rdr0-batch128-lr001-glove_with_stop_nonlemmatized-sampling_none-99-100-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-dr0-rdr0-batch128-lr001-glove_with_stop_nonlemmatized-sampling_none-99-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-dr0-rdr0-batch128-lr001-glove_with_stop_nonlemmatized-sampling_none-99-100-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-dr0-rdr0-batch128-lr001-glove_with_stop_nonlemmatized-sampling_none-99-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl...
# loading LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl...
# loading LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl...
# loading LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl...
# loading LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl...
# loading LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl...
# loading LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-997682-100-star_rating-history.pkl...
# loading LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-997682-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16_1345-1x16-glove_with_stop_nonlemmatized-sampling_none-931734-100-star_rating-history.pkl...
# loading LSTMB16_1345-1x16-glove_with_stop_nonlemmatized-sampling_none-931734-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16_145-1x16-glove_with_stop_nonlemmatized-sampling_none-841233-100-star_rating-history.pkl...
# loading LSTMB16_145-1x16-glove_with_stop_nonlemmatized-sampling_none-841233-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB16_15-1x16-glove_with_stop_nonlemmatized-sampling_none-675121-100-star_rating-history.pkl...
# loading LSTMB16_15-1x16-glove_with_stop_nonlemmatized-sampling_none-675121-100-star_rating-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB128-1x128-dr0-rdr0-batch128-lr01-glove_with_stop_nonlemmatized-sampling_none-49887-100-review_body-history.pkl...
# loading LSTMB128-1x128-dr0-rdr0-batch128-lr01-glove_with_stop_nonlemmatized-sampling_none-49887-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB128-1x128-dr0-rdr0-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-49887-100-review_body-history.pkl...
# loading LSTMB128-1x128-dr0-rdr0-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-49887-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB128-1x128-dr0-rdr0-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-49887-100-review_body-history.pkl...
# loading LSTMB128-1x128-dr0-rdr0-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-49887-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-dr0-rdr0-batch0-lr001-glove_with_stop_nonlemmatized-sampling_none-50k-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-dr0-rdr0-batch0-lr001-glove_with_stop_nonlemmatized-sampling_none-50k-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-dr0-rdr0-batch0-lr01-glove_with_stop_nonlemmatized-sampling_none-50k-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-dr0-rdr0-batch0-lr01-glove_with_stop_nonlemmatized-sampling_none-50k-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-dr0-rdr0-batch0-lr01-glove_with_stop_nonlemmatized-sampling_none-50k-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-dr0-rdr0-batch0-lr01-glove_with_stop_nonlemmatized-sampling_none-50k-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-dr0-rdr0-batch0-lr01-glove_with_stop_nonlemmatized-sampling_none-50k-review_body-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-dr0-rdr0-batch0-lr01-glove_with_stop_nonlemmatized-sampling_none-50k-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-dr0-rdr0-batch128-lr01-glove_with_stop_nonlemmatized-sampling_none-50k-review_body-v1-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-dr0-rdr0-batch128-lr01-glove_with_stop_nonlemmatized-sampling_none-50k-review_body-v1-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-dr0-rdr2-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-500k-review_body-v1-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-dr0-rdr2-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-500k-review_body-v1-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-dr0-rdr2-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-500k-review_body-v1-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-dr0-rdr2-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-500k-review_body-v1-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl...
# loading LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl
# converting network history drive/My Drive/Springboard/capstone/reports/test-LSTMB128-1x128-dr2-rdr2-batch128-lr01-glove_with_stop_nonlemmatized-sampling_none-1m-review_body-v1-history.pkl...
# Cannot locate: ../..//reports/test-LSTMB128-1x128-dr2-rdr2-batch128-lr01-glove_with_stop_nonlemmatized-sampling_none-1m-review_body-v1-history.pkl
#    network_history_file                                    network_history
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN  {"loss": [0.1435026780157967, 0.09747473491591...
# 3                   NaN  {"loss": [0.1704080996563167, 0.11089829540018...
# 4                   NaN  {"loss": [0.22036331948561838, 0.1419918946629...
# ..                  ...                                                ...
# 72                  NaN                                                NaN
# 73                  NaN                                                NaN
# 74                  NaN                                                NaN
# 75                  NaN  {"loss": [1.1470818519592285, 1.01992619037628...
# 76                  NaN                                                NaN
#
# [77 rows x 2 columns]
# Saving 2-column-converted-network-history-report.csv
#
#
# Reading 2019-11-run_classifiers-50k-KNN-report.csv
# Backing up to 2019-11-run_classifiers-50k-KNN-report.csv.pre-network-history
#
#
# Reading LSTMB16_dr2_rdr2_batch128_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv
# Backing up to LSTMB16_dr2_rdr2_batch128_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [1.376781940460205, 1.293714642524719...
# Saving LSTMB16_dr2_rdr2_batch128_lr001-glove_with_stop_nonlemmatized-dl_prototype-report.csv
#
#
# Reading 2019-07-25-DNN_protype-report.csv
# Backing up to 2019-07-25-DNN_protype-report.csv.pre-network-history
# Nothing to convert 2019-07-25-DNN_protype-report.csv
# Saving 2019-07-25-DNN_protype-report.csv
#
#
# Reading 2019-11-05-dl_prototype-report.csv
# Backing up to 2019-11-05-dl_prototype-report.csv.pre-network-history
# converting network history <tensorflow.python.keras.callbacks.History object at 0x7fde4637aa58>...
# Cannot locate: ../..//reports/<tensorflow.python.keras.callbacks.History object at 0x7fde4637aa58>
# converting network history <tensorflow.python.keras.callbacks.History object at 0x7f37f08e8dd8>...
# Cannot locate: ../..//reports/<tensorflow.python.keras.callbacks.History object at 0x7f37f08e8dd8>
# Nothing to convert 2019-11-05-dl_prototype-report.csv
# Saving 2019-11-05-dl_prototype-report.csv
#
#
# Reading dl_prototype-report.csv
# Backing up to dl_prototype-report.csv.pre-network-history
#    network_history_file                                    network_history
# 0                   NaN  {"loss": [0.8880516886711121, 0.78742259740829...
# 1                   NaN  {"loss": [1.191777229309082, 1.069434523582458...
# 2                   NaN  {"loss": [1.191777229309082, 1.069434523582458...
# 3                   NaN  {"loss": [1.1562772989273071, 1.04725062847137...
# 4                   NaN  {"loss": [1.1562772989273071, 1.04725062847137...
# 5                   NaN  {"loss": [1.1599695682525635, 1.06588315963745...
# 6                   NaN  {"loss": [1.3346794843673706, 1.27253341674804...
# 7                   NaN                                                NaN
# Saving dl_prototype-report.csv

# %%
history_df = pd.DataFrame()


for key, value in history_dict.items():
  # print(f'{key} {value}')
  if len(value) > 0:
    for report in value:
      file = f'{REPORT_DIR}/{os.path.basename(report)}'
      if os.path.exists(file):
        print(f'Deleting {file}')
        os.remove(file)
      history_df = history_df.append({"report": key, "network_history_file": report}, ignore_index = True)

history_df.to_csv(f'{REPORT_DIR}/2-column-deleted-network-history-report.csv', index = False)
history_df
# Out:
# Deleting ../..//reports/biGRU16-1x16-glove-sampling_none-199134-100-star_rating-history.pkl
# Deleting ../..//reports/biGRU16-1x16-glove-sampling_none-497835-100-star_rating-history.pkl
# Deleting ../..//reports/biGRU16-1x16-glove-sampling_none-995688-100-star_rating-history.pkl
# Deleting ../..//reports/biGRU16-1x16-glove-sampling_none-2000000-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16_15-1x16-glove-sampling_none-673881-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16_15-1x16-glove-sampling_none-337040-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16_15-1x16-glove-sampling_none-134678-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16_15-1x16-glove-sampling_none-1352517-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16-1x16-glove-sampling_none-995688-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16_145-1x16-glove-sampling_none-839811-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16_1345-1x16-glove-sampling_none-929903-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16-1x16-glove_with_stop-sampling_none-997682-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16_15-1x16-glove_with_stop-sampling_none-675121-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16_1345-1x16-glove_with_stop-sampling_none-931734-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16_145-1x16-glove_with_stop-sampling_none-841233-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-997681-30-review_headline-history.pkl
# Deleting ../..//reports/LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-2244642-30-review_headline-history.pkl
# Deleting ../..//reports/LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-99772-100-review_body-history.pkl
# Deleting ../..//reports/LSTMB32-1x32-glove_with_stop_nonlemmatized-sampling_none-99772-100-review_body-history.pkl
# Deleting ../..//reports/LSTMB64-1x64-glove_with_stop_nonlemmatized-sampling_none-99772-100-review_body-history.pkl
# Deleting ../..//reports/LSTMB16-1x16-glove_with_stop_nonlemmatized_nodropout-sampling_none-99772-100-review_body-history.pkl
# Deleting ../..//reports/LSTMB16-1x16-batch_32-sampling_none-99772-100-review_body-history.pkl
# Deleting ../..//reports/LSTMB16-1x16-batch_64-sampling_none-99772-100-review_body-history.pkl
# Deleting ../..//reports/LSTMB16-1x16-batch_128-sampling_none-99772-100-review_body-history.pkl
# Deleting ../..//reports/LSTMB16-expandcontractions_removestopwords_lemmatized-1x16-expandcontractions_removestopwords_lemmatized-sampling_none-99567-100-review_body-history.pkl
# Deleting ../..//reports/LSTM16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl
# Deleting ../..//reports/LSTMB16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl
# Deleting ../..//reports/GRU16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl
# Deleting ../..//reports/biGRUB16-1x16-random_embedding-sampling_none-199538-100-review_body-history.pkl
# Deleting ../..//reports/CNN32-1x32-embedding_random-sampling_none-200k-review_body-v1-history.pkl
# Deleting ../..//reports/LSTMB128-1x128-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl
# Deleting ../..//reports/LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-498831-100-review_body-history.pkl
# Deleting ../..//reports/LSTMB16-1x16-glove_with_stop_nonlemmatized-sampling_none-997682-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16_1345-1x16-glove_with_stop_nonlemmatized-sampling_none-931734-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16_145-1x16-glove_with_stop_nonlemmatized-sampling_none-841233-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB16_15-1x16-glove_with_stop_nonlemmatized-sampling_none-675121-100-star_rating-history.pkl
# Deleting ../..//reports/LSTMB128-1x128-dr0-rdr0-batch128-lr01-glove_with_stop_nonlemmatized-sampling_none-49887-100-review_body-history.pkl
# Deleting ../..//reports/LSTMB128-1x128-dr0-rdr0-batch32-lr001-glove_with_stop_nonlemmatized-sampling_none-49887-100-review_body-history.pkl
#                                  network_history_file  \
# 0   drive/My Drive/Springboard/capstone/models/biG...
# 1   drive/My Drive/Springboard/capstone/models/biG...
# 2   drive/My Drive/Springboard/capstone/models/biG...
# 3   drive/My Drive/Springboard/capstone/models/biG...
# 4   drive/My Drive/Springboard/capstone/reports/LS...
# 5   drive/My Drive/Springboard/capstone/reports/LS...
# 6   drive/My Drive/Springboard/capstone/reports/LS...
# 7   drive/My Drive/Springboard/capstone/reports/LS...
# 8   drive/My Drive/Springboard/capstone/reports/LS...
# 9   drive/My Drive/Springboard/capstone/reports/LS...
# 10  drive/My Drive/Springboard/capstone/reports/LS...
# 11  drive/My Drive/Springboard/capstone/reports/LS...
# 12  drive/My Drive/Springboard/capstone/reports/LS...
# 13  drive/My Drive/Springboard/capstone/reports/LS...
# 14  drive/My Drive/Springboard/capstone/reports/LS...
# 15  drive/My Drive/Springboard/capstone/reports/LS...
# 16  drive/My Drive/Springboard/capstone/reports/LS...
# 17  drive/My Drive/Springboard/capstone//reports/L...
# 18  drive/My Drive/Springboard/capstone//reports/L...
# 19  drive/My Drive/Springboard/capstone//reports/L...
# 20  drive/My Drive/Springboard/capstone//reports/L...
# 21  drive/My Drive/Springboard/capstone//reports/L...
# 22  drive/My Drive/Springboard/capstone//reports/L...
# 23  drive/My Drive/Springboard/capstone//reports/L...
# 24  drive/My Drive/Springboard/capstone//reports/L...
# 25  drive/My Drive/Springboard/capstone//reports/L...
# 26  drive/My Drive/Springboard/capstone//reports/L...
# 27  drive/My Drive/Springboard/capstone//reports/L...
# 28  drive/My Drive/Springboard/capstone//reports/L...
# 29  drive/My Drive/Springboard/capstone//reports/L...
# 30  drive/My Drive/Springboard/capstone//reports/L...
# 31  drive/My Drive/Springboard/capstone//reports/L...
# 32  drive/My Drive/Springboard/capstone//reports/L...
# 33  drive/My Drive/Springboard/capstone//reports/L...
# 34  drive/My Drive/Springboard/capstone//reports/G...
# 35  drive/My Drive/Springboard/capstone/reports/GR...
# 36  drive/My Drive/Springboard/capstone/reports/bi...
# 37  drive/My Drive/Springboard/capstone/reports/CN...
# 38  drive/My Drive/Springboard/capstone/reports/LS...
# 39  drive/My Drive/Springboard/capstone/reports/LS...
# 40  drive/My Drive/Springboard/capstone/reports/LS...
# 41  drive/My Drive/Springboard/capstone/reports/LS...
# 42  drive/My Drive/Springboard/capstone/reports/LS...
# 43  drive/My Drive/Springboard/capstone/reports/LS...
# 44  drive/My Drive/Springboard/capstone/reports/LS...
# 45  drive/My Drive/Springboard/capstone/reports/LS...
# 46  drive/My Drive/Springboard/capstone/reports/LS...
# 47  drive/My Drive/Springboard/capstone/reports/LS...
# 48  drive/My Drive/Springboard/capstone/reports/LS...
# 49  drive/My Drive/Springboard/capstone/reports/LS...
# 50  drive/My Drive/Springboard/capstone/reports/LS...
# 51  drive/My Drive/Springboard/capstone/reports/LS...
# 52  drive/My Drive/Springboard/capstone/reports/LS...
#
#                                            report
# 0         glove_embedding-dl_prototype-report.csv
# 1         glove_embedding-dl_prototype-report.csv
# 2         glove_embedding-dl_prototype-report.csv
# 3         glove_embedding-dl_prototype-report.csv
# 4   2-column-converted-network-history-report.csv
# 5   2-column-converted-network-history-report.csv
# 6   2-column-converted-network-history-report.csv
# 7   2-column-converted-network-history-report.csv
# 8   2-column-converted-network-history-report.csv
# 9   2-column-converted-network-history-report.csv
# 10  2-column-converted-network-history-report.csv
# 11  2-column-converted-network-history-report.csv
# 12  2-column-converted-network-history-report.csv
# 13  2-column-converted-network-history-report.csv
# 14  2-column-converted-network-history-report.csv
# 15  2-column-converted-network-history-report.csv
# 16  2-column-converted-network-history-report.csv
# 17  2-column-converted-network-history-report.csv
# 18  2-column-converted-network-history-report.csv
# 19  2-column-converted-network-history-report.csv
# 20  2-column-converted-network-history-report.csv
# 21  2-column-converted-network-history-report.csv
# 22  2-column-converted-network-history-report.csv
# 23  2-column-converted-network-history-report.csv
# 24  2-column-converted-network-history-report.csv
# 25  2-column-converted-network-history-report.csv
# 26  2-column-converted-network-history-report.csv
# 27  2-column-converted-network-history-report.csv
# 28  2-column-converted-network-history-report.csv
# 29  2-column-converted-network-history-report.csv
# 30  2-column-converted-network-history-report.csv
# 31  2-column-converted-network-history-report.csv
# 32  2-column-converted-network-history-report.csv
# 33  2-column-converted-network-history-report.csv
# 34  2-column-converted-network-history-report.csv
# 35  2-column-converted-network-history-report.csv
# 36  2-column-converted-network-history-report.csv
# 37  2-column-converted-network-history-report.csv
# 38  2-column-converted-network-history-report.csv
# 39  2-column-converted-network-history-report.csv
# 40  2-column-converted-network-history-report.csv
# 41  2-column-converted-network-history-report.csv
# 42  2-column-converted-network-history-report.csv
# 43  2-column-converted-network-history-report.csv
# 44  2-column-converted-network-history-report.csv
# 45  2-column-converted-network-history-report.csv
# 46  2-column-converted-network-history-report.csv
# 47  2-column-converted-network-history-report.csv
# 48  2-column-converted-network-history-report.csv
# 49  2-column-converted-network-history-report.csv
# 50  2-column-converted-network-history-report.csv
# 51  2-column-converted-network-history-report.csv
# 52  2-column-converted-network-history-report.csv
